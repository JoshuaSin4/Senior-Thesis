# %%
import numpy as np

# %%
sample1=np.load('input100sample50.npz')
tau_mem = np.arange(1e-4, 1e-2, 2e-4)

# %%
sample1['acc_list' ]
# Out:
# array([0.65234375, 0.67578125, 0.69921875, 0.66015625, 0.69140625,
#        0.6953125 , 0.7109375 , 0.7109375 , 0.75      , 0.73828125,
#        0.74609375, 0.76171875, 0.76953125, 0.796875  , 0.7734375 ,
#        0.82421875, 0.8046875 , 0.84375   , 0.83984375, 0.8515625 ,
#        0.84765625, 0.85546875, 0.87109375, 0.87890625, 0.90234375,
#        0.8671875 , 0.86328125, 0.8984375 , 0.8984375 , 0.9140625 ,
#        0.90234375, 0.89453125, 0.921875  , 0.921875  , 0.92578125,
#        0.92578125, 0.9296875 , 0.9375    , 0.9375    , 0.9453125 ,
#        0.9453125 , 0.93359375, 0.93359375, 0.91796875, 0.90625   ,
#        0.91796875, 0.91015625, 0.9140625 , 0.94140625, 0.93359375])

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.set_xlabel("Values of tau membrane constant")
ax.set_ylabel("Accuracy")
ax.plot(tau_mem, sample1['acc_list'])
fig.savefig("accuracyvstau_mem.png")
