# %%
import os

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns

import torch
import torch.nn as nn
import torchvision

# %%
data = np.load("fan-out-he-uniform-initialization.npz")

# %%
data

# %%
data['loss_hist']
# Out:
# array([1.22457186, 0.53440323, 0.34966575, 0.25771592, 0.25065083,
#        0.25479389, 0.20961866, 0.15801514, 0.18309046, 0.1959089 ,
#        0.1281407 , 0.16366715, 0.12112761, 0.09115059, 0.10397959,
#        0.11238176, 0.12457995, 0.10764115, 0.10209364, 0.12569084,
#        0.05962581, 0.11058488, 0.07113703, 0.12845203, 0.11046013,
#        0.14688523, 0.08027862, 0.09996416, 0.10942567, 0.07211759,
#        0.06792459, 0.09324177, 0.10672297, 0.06636199, 0.07886435,
#        0.07588439, 0.05991282, 0.10242107, 0.08947977, 0.08486324])

# %%
plt.plot(np.diff(data['loss_hist']))

# %%
data1 = np.load("fan-in-he-uniform-initialization.npz")

# %%
plt.plot(np.diff(data1['loss_hist']))

# %%
data2 = np.load("fan-in-he-normal-initialization.npz")

# %%
plt.plot(np.diff(data2['loss_hist']))

# %%
data3 = np.load("fan-out-he-normal-initialization.npz")

# %%
plt.plot(np.diff(data3['loss_hist']))

# %%
data4 = np.load("xavier-normal-initialization.npz")

# %%
plt.plot(np.diff(data4['loss_hist']))

# %%
data5 = np.load("zenke-initialization.npz")

# %%
plt.plot(np.diff(data5['loss_hist']))

# %%
data6 = np.load("xavier-uniform-initialization.npz")

# %%
plt.plot(np.diff(data6['loss_hist']))
